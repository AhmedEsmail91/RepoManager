# %%
GITHUB_TOKEN = 'add_your_classic_token_here'  # Replace with your GitHub token
USERNAME = 'add_your_username_here'  # Replace with your GitHub username

# %%
from GithubRepoManager import GitHubRepoManager# Usage example:
manager = GitHubRepoManager(GITHUB_TOKEN, USERNAME)
manager.fetch_repos()
repos=manager.show_repos(limit=3)
# To delete by index:
# repos for any categorization, e.g., private or public
# numbers = [0, 1, 2]  # Replace with actual indices you want to delete
# uncomment the following line to delete
# manager.delete_repos_by_index([numbers])
# Out:
# Fetching repositories...
# ✅ Total repositories fetched: 30
#    Index                                    Full Name  Private Description
# 0      0                       AHMED168-ENG/chat-back     True   chat back
# 1      1               AhmedEsmail91/BackEndDaffodils     True
# 2      2  AhmedEsmail91/ChatBotWithAdmin-ClientPanels     True

# %%
repos
# Out:
#     Index                                          Full Name  Private  \
# 0       0                             AHMED168-ENG/chat-back     True
# 1       1                     AhmedEsmail91/BackEndDaffodils     True
# 2       2        AhmedEsmail91/ChatBotWithAdmin-ClientPanels     True
# 3       3                      AhmedEsmail91/Daffodil-Clinic     True
# 4       4                      AhmedEsmail91/daffodil_clinic     True
# 5       5                       AhmedEsmail91/eCinemaBooking     True
# 6       6             AhmedEsmail91/KnowledgeBaseCoreLaravel     True
# 7       7                          AhmedEsmail91/MyOwnKurick     True
# 8       8       AhmedEsmail91/PlayStationTimeCostCalculation     True
# 9       9                            AhmedEsmail91/TasksList     True
# 10     10                             AhmedEsmail91/WorkFlow     True
# 11     11             AhmedEsmail91/Workflows-Automation-n8n     True
# ...
